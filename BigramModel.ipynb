# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-2
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()  # you dont need to calculate during forwad pass
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# --2023-12-08 01:34:49--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.02s
#
# 2023-12-08 01:34:49 (51.1 MB/s) - ‘input.txt’ saved [1115394/1115394]
#
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.5130, val loss 2.5190
# step 200: train loss 2.3428, val loss 2.3247
# step 300: train loss 2.2243, val loss 2.2475
# step 400: train loss 2.1484, val loss 2.1962
# step 500: train loss 2.1000, val loss 2.1584
# step 600: train loss 2.0452, val loss 2.1059
# step 700: train loss 2.0245, val loss 2.1008
# step 800: train loss 1.9906, val loss 2.0791
# step 900: train loss 1.9553, val loss 2.0536
# step 1000: train loss 1.9284, val loss 2.0126
# step 1100: train loss 1.9185, val loss 2.0410
# step 1200: train loss 1.8766, val loss 1.9955
# step 1300: train loss 1.8774, val loss 1.9993
# step 1400: train loss 1.8614, val loss 1.9785
# step 1500: train loss 1.8342, val loss 1.9655
# step 1600: train loss 1.8331, val loss 1.9788
# step 1700: train loss 1.8214, val loss 1.9510
# step 1800: train loss 1.7904, val loss 1.9507
# step 1900: train loss 1.8124, val loss 1.9466
# step 2000: train loss 1.7877, val loss 1.9559
# step 2100: train loss 1.7761, val loss 1.9319
# step 2200: train loss 1.7722, val loss 1.9263
# step 2300: train loss 1.7757, val loss 1.9130
# step 2400: train loss 1.7663, val loss 1.8894
# step 2500: train loss 1.7499, val loss 1.9087
# step 2600: train loss 1.7505, val loss 1.9019
# step 2700: train loss 1.7463, val loss 1.9028
# step 2800: train loss 1.7614, val loss 1.9192
# step 2900: train loss 1.7553, val loss 1.9169
# step 3000: train loss 1.7467, val loss 1.8846
# step 3100: train loss 1.7297, val loss 1.9101
# step 3200: train loss 1.7183, val loss 1.8840
# step 3300: train loss 1.7259, val loss 1.8809
# step 3400: train loss 1.7150, val loss 1.8609
# step 3500: train loss 1.7195, val loss 1.8879
# step 3600: train loss 1.7035, val loss 1.9008
# step 3700: train loss 1.7020, val loss 1.8648
# step 3800: train loss 1.7122, val loss 1.8894
# step 3900: train loss 1.6921, val loss 1.8452
# step 4000: train loss 1.7026, val loss 1.8632
# step 4100: train loss 1.7018, val loss 1.8775
# step 4200: train loss 1.6881, val loss 1.8564
# step 4300: train loss 1.7079, val loss 1.8590
# step 4400: train loss 1.7054, val loss 1.8670
# step 4500: train loss 1.6959, val loss 1.8578
# step 4600: train loss 1.6883, val loss 1.8271
# step 4700: train loss 1.6903, val loss 1.8548
# step 4800: train loss 1.6739, val loss 1.8602
# step 4900: train loss 1.6749, val loss 1.8516
# step 5000: train loss 1.6723, val loss 1.8463
# step 5100: train loss 1.6793, val loss 1.8350
# step 5200: train loss 1.6603, val loss 1.8070
# step 5300: train loss 1.6718, val loss 1.8187
# step 5400: train loss 1.6649, val loss 1.8238
# step 5500: train loss 1.6576, val loss 1.8065
# step 5600: train loss 1.6694, val loss 1.8247
# step 5700: train loss 1.6683, val loss 1.8270
# step 5800: train loss 1.6493, val loss 1.8095
# step 5900: train loss 1.6609, val loss 1.8332
# step 6000: train loss 1.6527, val loss 1.8197
# step 6100: train loss 1.6587, val loss 1.8064
# step 6200: train loss 1.6633, val loss 1.8115
# step 6300: train loss 1.6430, val loss 1.8064
# step 6400: train loss 1.6473, val loss 1.8210
# step 6500: train loss 1.6457, val loss 1.7983
# step 6600: train loss 1.6384, val loss 1.7938
# step 6700: train loss 1.6409, val loss 1.8089
# step 6800: train loss 1.6435, val loss 1.8142
# step 6900: train loss 1.6424, val loss 1.8175
# step 7000: train loss 1.6347, val loss 1.8074
# step 7100: train loss 1.6438, val loss 1.8160
# step 7200: train loss 1.6282, val loss 1.8129
# step 7300: train loss 1.6344, val loss 1.8033
# step 7400: train loss 1.6375, val loss 1.8180
# step 7500: train loss 1.6280, val loss 1.8198
# step 7600: train loss 1.6286, val loss 1.8022
# step 7700: train loss 1.6233, val loss 1.7908
# step 7800: train loss 1.6350, val loss 1.7957
# step 7900: train loss 1.6310, val loss 1.7890
# step 8000: train loss 1.6372, val loss 1.8094
# step 8100: train loss 1.6321, val loss 1.8040
# step 8200: train loss 1.6285, val loss 1.8100
# step 8300: train loss 1.6272, val loss 1.8045
# step 8400: train loss 1.6294, val loss 1.7990
# step 8500: train loss 1.6342, val loss 1.8027
# step 8600: train loss 1.6242, val loss 1.8004
# step 8700: train loss 1.6140, val loss 1.7937
# step 8800: train loss 1.6119, val loss 1.8112
# step 8900: train loss 1.6264, val loss 1.7855
# step 9000: train loss 1.6250, val loss 1.7961
# step 9100: train loss 1.6150, val loss 1.7862
# step 9200: train loss 1.6199, val loss 1.7805
# step 9300: train loss 1.6079, val loss 1.7697
# step 9400: train loss 1.6140, val loss 1.7835
# step 9500: train loss 1.6100, val loss 1.7956
# step 9600: train loss 1.6128, val loss 1.7862
# step 9700: train loss 1.6018, val loss 1.7666
# step 9800: train loss 1.6010, val loss 1.7863
# step 9900: train loss 1.6116, val loss 1.7806
# step 9999: train loss 1.5955, val loss 1.7734
#
# And they bride within a baws imbaiden boby, and Sagraves mealied
# her rabth foul hath bud widing water witned and not comzonound own procfultion.
#
# VOLWARD:
# What's is eye, I, will it therev the heart longure.
#
# WARWICK:
# Nind me upolixed once, you caments' have, my liked knew pate at gond:
# I what methink only so when evily, where dost what which he pooper uncourune kindnesrupt,
# I'll; if his whither inlectation.
#
# Provost:
# Heream I such all, fight adial as a ght to upon miscaar tey it-place
# And for his neely oker, griline inthing han
# bearded, it-ely; and we mealr and what such he have us, I have much a some stimects lord
# I iark of alling thou earted he mover: imder?
#
# Less:
# And meety Hows so upon thou fellow,
# Thy better oversun if him it, I confortunar.
#
# CORIOLANUSON:
# He citio's me! I with self mond told lack.
#
# Privoser:
# Welcome, if I it have been in the eatures, this of tiund.
#
# DUKE OF AUMERLE:
# Your anor what thou will sile Eicliest marry, and the pribed
# By thine, Your thing thus young;
# So enemy confer we soft it, I wound whench night is, I can this dock,
# One actions, and men, mercution sist tender,
# My life-voice great of would, child friend!
#
# BINA:
# AI have a canion all, and be any ink.
#
# LUCIO:
# O, there's woes
# Autiwand it what see would in this chiold's leave
# That witness of gruther creators,
# The so voward murder, and but but of it is clidie.
#
# Provose:
# For they sich a subs: as war nigne,
# Once of comman; but a hollow unhinanceant om Twice tend, and light insome you,
# But only lattoned in me it kill'd, I them with tembs;
# Rithat wilk virture my love meanted;
# Our fellow arms is above wall previliant knew in the happy,
# Bolorrows the rished and light in, give after
# My mah, sir: and o' the hath an have bland of live,
# And lone but was I have power, Ha, of monder
# Aolamber her at repeech any in a gack.
#
# KING HENRY VI:
# Your lifd he hung foold out a for of your quoth,
# Curseluck promination, whese that a hath.
#
# EDWARD:
# Which youard you briin shall'nefter, his such I hell hand.
# If all I
